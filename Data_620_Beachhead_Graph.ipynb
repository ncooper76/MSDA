# %% [raw]
# In this assignment I am tasked with creating a beachhead graph of a simple network. The network I chose is a subset of my facebook page, expanding out a little to a former roomates facebook page. I used only first names and nicknames to help protect the privacy of the friend subset I selected.

# %% [markdown]
# Since I run Pyhton 3, and GraphLab is not compatable with that version, I used NetworkX to create the graph. Furthermore, the text Social Network Analysis for Startups had a couple examples for a network graph, so I used those as a template. I created the data for the netowrk using gedit on my Ubuntu machine and networkx to draw the graph.

# %%
import matplotlib.pyplot as plt
import networkx as net
import requests
import warnings
warnings.filterwarnings("ignore")
# %matplotlib notebook

# Loading data directly from Github has a formatting error
#file = requests.get('https://raw.githubusercontent.com/ncooper76/MSDA/master/tiny.net')
#file = file.text
#tiny = net.read_pajek(file)

#loading data from a local file seems to work okay
tiny = net.read_pajek('C:\\Users\\Nate\\Documents\\Python_Scripts\\tiny.net') #for Windows
#tiny = net.read_pajek('/home/nathan/Scripts/Python/SNABook/chapter1/tiny.net') #for Linux
plt.subplot(3,1,1)
net.draw(tiny,with_labels = True)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# To explore the features of networkx, I will now make a few graphs using different methods.
#
# First I will make a Kite Graph like that featured in the write-up for this assignment:

# %%
g = net.generators.small.krackhardt_kite_graph()
plt.subplot(3,1,2)
net.draw(g, with_labels = True)

# %% [markdown]
# Now I will make an edge list bases on the tiny.net data.

# %%
tiny_edge = ["1 2 1",
             "1 3 1",
             "1 4 1",
             "1 5 1",
             "1 6 1",
             "1 7 1",
             "1 8 1",
             "1 9 1",
             "1 10 1",
             "2 3 1",
             "2 4 1",
             "2 5 1",
             "2 6 1",
             "2 7 1",
             "2 9 1",
             "3 4 1",
             "3 5 1",
             "4 5 1",
             "4 6 1",
             "6 7 1",
             "6 9 1",
             "6 10 1"]
h = net.parse_edgelist(tiny_edge, nodetype = int,data=(('weight',int),))
plt.subplot(3,1,3)
net.draw(h, with_labels = True)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
